# %% [markdown]
# # Tutorial: Batch Processing
#
# This tutorial explains how to use the batch processing script to solve CommonRoad planning problems in parallel. The configuration for batch processing is stored in `batch_processing_config.yaml`. Some of the parameters are explained as follows:
# * **input_path**: input directory of your intended CommonRoad scenarios.
# * **output_path**: output directory of CommonRoad solution files.
# * **overwrite**: whether the existing solution files should be overwritten.
# * **validate_solution**: check the validity of the solutions with the feasibility checker.
# * **num_worker_processes**: the number of parallel executions of motion planners.
#
# Parameters specified under the `default` block will be applied to all scenarios. If you wish to specify a different paramter for specific scenarios, simply insert a new block with the content of the `default` block copied, and overwrite parameters therein. This new block should be named after the ID of the sceanrio that you wish to aplly the parameters to. Related parameters are explained as follows:
# * **vehicle_model**: model of the vehicle, valid values: **PM, KS, ST and MB**. Refer to [Vehicle Models](https://gitlab.lrz.de/tum-cps/commonroad-vehicle-models/-/blob/master/vehicleModels_commonRoad.pdf) for more information.
# * **vehicle_type**: type of the vehicle, valid values: **FORD_ESCORT, BMW_320i and VW_VANAGON**.
# * **cost_function**: id of cost function. Refer to [Cost Functions](https://gitlab.lrz.de/tum-cps/commonroad-cost-functions/-/blob/master/costFunctions_commonRoad.pdf) for more information.
# * **planner**: the planner that is used to solve for solutions, possible values are: bfs, dfs, dls, ucs, gbfs, astar, student, student_example
# * **planning_problem_idx**: index of the planning problem. for cooperative scenarios: 0, 1, 2, ..., otherwise: 0
# * **max_tree_depth**: maximum depth of the search tree
# * **timeout**: timeout time for motion planner [s].
#
# Note: the paths can either be **relative** or **absolute**.
# To start the search with batch processing, you can either directly run `SMP/batch_processing/batch_processing_parallel.py` in IDEs (e.g. PyCharm) with `commonroad-search/` marked as sources root, or run the following script.

# %% [markdown]
# ## Parallel Batch Processing
# In parallel batch processing, the search are carried out on multiple threads simultaneously. This reduces the overall time required to test your algorithm on all the given scenarios. One drawback is that it is not very easy to debug your code with parallel batch processing.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

# add the folder containing batch processing script into python path
sys.path.append(os.path.join(os.getcwd(), "../../"))

import SMP.batch_processing.batch_processing_parallel as batch_processing_parallel

# %%
if __name__ == '__main__':
    batch_processing_parallel.run_parallel_processing()
# Out:
# Config file loaded and logger created.
# 18 scenarios skipped.
# ScenarioLoader Mode <DEFAULT>
# Run on all scenarios, except the skipped scenarios
# Number of scenarios: 500
# Automaton loaded for vehicle type: BMW_320i
# Motion planner: astar
# Number of parallel processes: 6
#
# ==================================================
# Scenarios processed:	         1
# Solution found:               	         1
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	         2
# Solution found:               	         2
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	         3
# Solution found:               	         3
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	         4
# Solution found:               	         3
# Solution found but invalid:   	         1
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	         5
# Solution found:               	         3
# Solution found but invalid:   	         2
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	         6
# Solution found:               	         3
# Solution found but invalid:   	         3
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	         7
# Solution found:               	         3
# Solution found but invalid:   	         3
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	         8
# Solution found:               	         4
# Solution found but invalid:   	         3
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	         9
# Solution found:               	         4
# Solution found but invalid:   	         4
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	        10
# Solution found:               	         4
# Solution found but invalid:   	         5
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	        11
# Solution found:               	         5
# Solution found but invalid:   	         5
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	        12
# Solution found:               	         6
# Solution found but invalid:   	         5
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	        13
# Solution found:               	         6
# Solution found but invalid:   	         5
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	        14
# Solution found:               	         6
# Solution found but invalid:   	         6
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	        15
# Solution found:               	         6
# Solution found but invalid:   	         7
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	        16
# Solution found:               	         7
# Solution found but invalid:   	         7
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	        17
# Solution found:               	         7
# Solution found but invalid:   	         8
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	        18
# Solution found:               	         7
# Solution found but invalid:   	         9
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	        19
# Solution found:               	         7
# Solution found but invalid:   	        10
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# stopping execution
# ==============================        Search Results        ==============================
# [ARG_Carcarana-11_1_T-1        ]	<SUCCESS>	 Time [ms]:	  4788
# [ARG_Carcarana-13_1_T-1        ]	<SUCCESS>	 Time [ms]:	  2107
# [ARG_Carcarana-2_3_T-1         ]	<SUCCESS>	 Time [ms]:	  4210
# [ARG_Carcarana-3_3_T-1         ]	<INVALID>	 Time [ms]:	  6599
# [ARG_Carcarana-5_2_T-1         ]	<INVALID>	 Time [ms]:	  3503
# [ARG_Carcarana-7_1_T-1         ]	<INVALID>	 Time [ms]:	  4253
# [ARG_Carcarana-8_4_T-1         ]	<FAILURE>	 Time [ms]:	  1972
# [ARG_Carcarana-9_2_T-1         ]	<SUCCESS>	 Time [ms]:	  4442
# [BEL_Aarschot-11_1_T-1         ]	<INVALID>	 Time [ms]:	  1494
# [BEL_Aarschot-1_2_T-1          ]	<INVALID>	 Time [ms]:	  2579
# [BEL_Aarschot-3_1_T-1          ]	<SUCCESS>	 Time [ms]:	  1099
# [BEL_Aarschot-5_1_T-1          ]	<SUCCESS>	 Time [ms]:	  2114
# [BEL_Aarschot-6_1_T-1          ]	<FAILURE>	 Time [ms]:	  1836
# [BEL_Beringen-1_1_T-1          ]	<INVALID>	 Time [ms]:	  2343
# [BEL_Beringen-8_1_T-1          ]	<INVALID>	 Time [ms]:	  1135
# [BEL_Nivelles-10_1_T-1         ]	<SUCCESS>	 Time [ms]:	  1187
# [BEL_Nivelles-16_2_T-1         ]	<INVALID>	 Time [ms]:	   738
# [BEL_Nivelles-18_2_T-1         ]	<INVALID>	 Time [ms]:	  2711
# [BEL_Nivelles-19_1_T-1         ]	<INVALID>	 Time [ms]:	  2239
# ==============================        Solution found        ==============================
# 	- ARG_Carcarana-11_1_T-1
# 	- ARG_Carcarana-13_1_T-1
# 	- ARG_Carcarana-2_3_T-1
# 	- ARG_Carcarana-9_2_T-1
# 	- BEL_Aarschot-3_1_T-1
# 	- BEL_Aarschot-5_1_T-1
# 	- BEL_Nivelles-10_1_T-1
# ==============================  Solution found but invalid  ==============================
# 	- ARG_Carcarana-3_3_T-1
# 	- ARG_Carcarana-5_2_T-1
# 	- ARG_Carcarana-7_1_T-1
# 	- BEL_Aarschot-11_1_T-1
# 	- BEL_Aarschot-1_2_T-1
# 	- BEL_Beringen-1_1_T-1
# 	- BEL_Beringen-8_1_T-1
# 	- BEL_Nivelles-16_2_T-1
# 	- BEL_Nivelles-18_2_T-1
# 	- BEL_Nivelles-19_1_T-1
# ==============================      Solution not found      ==============================
# 	- ARG_Carcarana-8_4_T-1
# 	- BEL_Aarschot-6_1_T-1
#
# ==============================        Result Summary        ==============================
# Total number of scenarios:  	       500
# Solution found:               	         7
# Solution found but invalid:   	        10
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0

# %% [markdown]
# ## Sequential Batch Processing
#
# Alternatively, one can use the `SMP/batch_processing/batch_processing_sequential.py` script to carry out the search sequentially on a single thread. This is a more user-friendly approach if you wish you debug your code in IDES (e.g. creating breakpoints in PyCharm) but still have it run against multiple scenarios.

# %%
from SMP.batch_processing.batch_processing_sequential import run_sequential_processing
run_sequential_processing()
# Out:
# Config file loaded and logger created.
# 18 scenarios skipped.
# ScenarioLoader Mode <DEFAULT>
# Run on all scenarios, except the skipped scenarios
# Number of scenarios: 500
# Automaton loaded for vehicle type: BMW_320i
# Motion planner: astar
#
# ==================================================
# Scenarios processed:	         1
# Solution found:               	         1
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenarios processed:	         2
# Solution found:               	         2
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 2
#       1 from SMP.batch_processing.batch_processing_sequential import run_sequential_processing
# ----> 2 run_sequential_processing()
#
# File E:\dev\beta\commonroad-search-master\commonroad-search-master\tutorials\4_batch_processing\../..\SMP\batch_processing\batch_processing_sequential.py:14, in run_sequential_processing()
#      10 configuration, logger, scenario_loader, def_automaton, result_dict = hf.init_processing(
#      11     "Sequential Batch Processor", for_multi_processing=False)
#      13 for idx, scenario_id in enumerate(scenario_loader.scenario_ids):
# ---> 14     ret_result = debug_scenario(scenario_id=scenario_id, scenario_loader=scenario_loader,
#      15                                 configuration_dict=configuration,
#      16                                 def_automaton=def_automaton, logger=logger)
#      17     postprocess_result(ret_result, result_dict, scenario_id, scenario_loader, configuration)
#      18     result_dict["started_processing"] += 1
#
# File E:\dev\beta\commonroad-search-master\commonroad-search-master\tutorials\4_batch_processing\../..\SMP\batch_processing\process_scenario.py:332, in debug_scenario(scenario_id, scenario_loader, configuration_dict, def_automaton, logger, verbose)
#     324 if (
#     325         res_local.result != ResultType.FAILURE and res_local.result != ResultType.TIMEOUT and res_local.result != ResultType.EXCEPTION):
#     326
#     327     # validate solution, save it only if it is valid
#     329     validate_solution = hf.str2bool(
#     330         configuration_dict['setting']['validate_solution'])
# --> 332     validation_result = validate_solution_before_saving(scenario, planning_problem_set, planning_problem_id,
#     333                                                         scenario_config, res_local.search_time_sec,
#     334                                                         res_local.list_of_list_of_states, validate_solution,
#     335                                                         logger)
#     337     is_valid_solution, planning_problem_solution, solution = validation_result
#     339     if is_valid_solution:
#
# File E:\dev\beta\commonroad-search-master\commonroad-search-master\tutorials\4_batch_processing\../..\SMP\batch_processing\process_scenario.py:87, in validate_solution_before_saving(scenario, planning_problem_set, planning_problem_id, config, computation_time_in_sec, list_of_list_of_states, validate_solution, logger)
#      84 solution = Solution(scenario.scenario_id, [pps], computation_time=computation_time_in_sec)
#      86 if validate_solution:
# ---> 87     if valid_solution(scenario, planning_problem_set, solution)[0]:
#      88         solution_valid = True
#      89     else:
#
# File E:\Miniconda3\envs\common_8_10\lib\site-packages\commonroad_dc\feasibility\solution_checker.py:346, in valid_solution(scenario, planning_problem_set, solution)
#     315 def valid_solution(scenario: Scenario,
#     316                    planning_problem_set: PlanningProblemSet,
#     317                    solution: Solution) -> Tuple[bool, Dict[int, Tuple[bool, Trajectory, Trajectory]]]:
#     318     """
#     319     Checks whether a solution is valid or not by checking
#     320         - Solution has solved all planning problems of the scenario (solved_all_problems)
#    (...)
#     339         inputs. Raises SolutionCheckerException if any of the checks fail.
#     340     """
#     341     valid = all([
#     342         solved_all_problems(planning_problem_set, solution),
#     343         goal_reached(scenario, planning_problem_set, solution),
#     344         starts_at_correct_state(solution, planning_problem_set),
#     345         not obstacle_collision(scenario, planning_problem_set, solution),
# --> 346         not boundary_collision(scenario, planning_problem_set, solution),
#     347         not ego_collision(scenario, planning_problem_set, solution)
#     348     ])
#     349     results = solution_feasible(solution, scenario.dt, planning_problem_set)
#     350     all_feasible = all([
#     351         result[0]
#     352         for pp_id, result in results.items()
#     353     ])
#
# File E:\Miniconda3\envs\common_8_10\lib\site-packages\commonroad_dc\feasibility\solution_checker.py:178, in boundary_collision(scenario, planning_problem_set, solution)
#     167 def boundary_collision(scenario: Scenario,
#     168                        planning_problem_set: PlanningProblemSet,
#     169                        solution: Solution) -> bool:
#     170     """
#     171     Checks whether the ego vehicles go out of lanelet boundaries.
#     172
#    (...)
#     176     :return: False if the ego vehicles stay in lanes. Raises CollisionException if there are any boundary collisions.
#     177     """
# --> 178     collision_checker = _construct_boundary_checker(scenario)
#     179     for pp_solution in solution.planning_problem_solutions:
#     180         collision_object = _create_pp_solution_collision_object(planning_problem_set, pp_solution,
#     181                                                                 scenario.dt)
#
# File E:\Miniconda3\envs\common_8_10\lib\site-packages\commonroad_dc\feasibility\solution_checker.py:73, in _construct_boundary_checker(scenario)
#      71 def _construct_boundary_checker(scenario: Scenario) -> CollisionChecker:
#      72     build = ['section_triangles', 'triangulation']
# ---> 73     boundary = construction.construct(scenario, build)
#      74     road_boundary_shape_list = []
#      75     initial_state = None
#
# File E:\Miniconda3\envs\common_8_10\lib\site-packages\commonroad_dc\boundary\construction.py:139, in construct(scenario, build_order, boundary_margin)
#     136 # min and max coordinates of the scenario
#     137 corners = scenario_bounds.calc_corners(lanelets, boundary_margin)
# --> 139 build(build_order)
#     141 return handle_return()
#
# File E:\Miniconda3\envs\common_8_10\lib\site-packages\commonroad_dc\boundary\construction.py:86, in construct.<locals>.build(orders)
#      84     order = order[0]
#      85 if order in options:
# ---> 86     options.get(order)()
#
# File E:\Miniconda3\envs\common_8_10\lib\site-packages\commonroad_dc\boundary\construction.py:74, in construct.<locals>.build.<locals>.<lambda>()
#      68     triangle_builder.build_offset_section_triangles(lanelet_network, critical_area, width)
#      70 params = {}
#      71 options = {
#      72     "simple_triangles": lambda: build_simple_triangles(),
#      73     "section_triangles": lambda: build_section_triangles(),
# ---> 74     "triangulation": lambda: help_triangulate(params),
#      75     "critical_area": lambda: build_critical_area(params),
#      76 }
#      77 for order in orders:
#      78     params = {}
#
# File E:\Miniconda3\envs\common_8_10\lib\site-packages\commonroad_dc\boundary\construction.py:59, in construct.<locals>.build.<locals>.help_triangulate(params)
#      57     points = [point for lane_section in lanelet_bounds.lane_hull(lanelet_network) for point in lane_section]
#      58     hull_points = simple_minkowski(points, offset, road)
# ---> 59     triangle_builder.triangulate(bounds, hull_points, road, triangulation, params)
#      60 else:
#      61     corner_vertices = [(corners[0], corners[2]), (corners[1], corners[2]),
#      62                        (corners[1], corners[3]), (corners[0], corners[3])]
#
# File E:\Miniconda3\envs\common_8_10\lib\site-packages\commonroad_dc\boundary\triangle_builder.py:150, in triangulate(bounds, vertices, input_triangles, output_triangles, params)
#     148 vertices = [node for node in nodeset]
#     149 # the if condition eliminates edges that have two identical vertices as endpoints
# --> 150 segset = set([map_segment(entry, vertices) for entry in segset if len(entry) == 2])
#     151 vertices = np.array(vertices)
#     152 segments = np.array([seg for seg in segset])
#
# File E:\Miniconda3\envs\common_8_10\lib\site-packages\commonroad_dc\boundary\triangle_builder.py:150, in <listcomp>(.0)
#     148 vertices = [node for node in nodeset]
#     149 # the if condition eliminates edges that have two identical vertices as endpoints
# --> 150 segset = set([map_segment(entry, vertices) for entry in segset if len(entry) == 2])
#     151 vertices = np.array(vertices)
#     152 segments = np.array([seg for seg in segset])
#
# File E:\Miniconda3\envs\common_8_10\lib\site-packages\commonroad_dc\boundary\triangle_builder.py:144, in triangulate.<locals>.map_segment(entry, vertices)
#     142 def map_segment(entry, vertices):
#     143     v1, v2 = entry
# --> 144     v1_index = [i for i, entry in enumerate(vertices) if entry == v1][0]
#     145     v2_index = [i for i, entry in enumerate(vertices) if entry == v2][0]
#     146     return (v1_index, v2_index)
#
# File E:\Miniconda3\envs\common_8_10\lib\site-packages\commonroad_dc\boundary\triangle_builder.py:144, in <listcomp>(.0)
#     142 def map_segment(entry, vertices):
#     143     v1, v2 = entry
# --> 144     v1_index = [i for i, entry in enumerate(vertices) if entry == v1][0]
#     145     v2_index = [i for i, entry in enumerate(vertices) if entry == v2][0]
#     146     return (v1_index, v2_index)
#
# KeyboardInterrupt:
